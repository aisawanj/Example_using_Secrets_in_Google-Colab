# %% [markdown]
# <a href="https://colab.research.google.com/github/aisawanj/Example_using_Secrets_in_Google_Colab/blob/main/Example_using_Secrets_in_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Example of connecting database (MySQL) using Secrets in Google Colab**
#
# **Key Features**
# 1. Simplify code configuration by securely storing environment variables, file paths, or keys.
# 2. Secret names cannot include spaces.
# 3. Sharing a notebook won’t expose stored secrets (remain confidential)

# %% [markdown]
# ### **Reference using Secrets on Google Colab**
#
# ![image.png](data:image/png;base64,...)

# %%
# Create a variable from the default configuration of Secret names and values
from google.colab import userdata
MYSQL_HOST = userdata.get('MYSQL_HOST')
MYSQL_PORT = int(userdata.get('MYSQL_PORT'))
MYSQL_USER = userdata.get('MYSQL_USER')
MYSQL_PASSWORD = userdata.get('MYSQL_PASSWORD')
MYSQL_DB = userdata.get('MYSQL_DB')
MYSQL_CHARSET = userdata.get('MYSQL_CHARSET')

# %%
# Install pymysql
# !pip install pymysql
import pymysql

# Connect to the database
connection = pymysql.connect(host = MYSQL_HOST,
                             port = MYSQL_PORT,
                             user = MYSQL_USER,
                             password = MYSQL_PASSWORD,
                             db = MYSQL_DB,
                             charset = MYSQL_CHARSET,
                             cursorclass = pymysql.cursors.DictCursor)
